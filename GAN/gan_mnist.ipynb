# %%
import keras
from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten
from keras.layers import BatchNormalization,LeakyReLU
from keras.models import Sequential, Model
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
keras.__version__
# Out:
# '3.4.1'

# %%
tf.__version__
# Out:
# '2.17.0'

# %%
np.__version__
# Out:
# '1.26.4'

# %%
#Define input image dimensions
#Large images take too much time and resources.
img_rows = 28
img_cols = 28
channels = 1
img_shape = (img_rows, img_cols, channels)

# %%
Reshape(img_shape)
# Out:
# <Reshape name=reshape, built=False>

# %%
def build_generator():
    noise_shape = (100,) #1D array of size 100 (latent vector / noise)

    #Define your generator network 
    #Here we are only using Dense layers. But network can be complicated based
    #on the application. For example, you can use VGG for super res. GAN.         
    model = Sequential()
    model.add(Dense(256, input_shape=noise_shape))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Dense(1024))
    model.add(LeakyReLU(alpha=0.2))
    model.add(BatchNormalization(momentum=0.8))
    
    model.add(Dense(np.prod(img_shape), activation='tanh'))
    model.add(Reshape(img_shape))

    model.summary()
    noise = Input(shape=noise_shape)
    img = model(noise)    #Generated image
    return Model(noise, img)

#Alpha — α is a hyperparameter which controls the underlying value to which the
#function saturates negatives network inputs.
#Momentum — Speed up the training

# %%
generator = build_generator()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 256)            │        25,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1024)           │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 784)            │       803,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_2 (Reshape)             │ (None, 28, 28, 1)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,493,520 (5.70 MB)
#  Trainable params: 1,489,936 (5.68 MB)
#  Non-trainable params: 3,584 (14.00 KB)

# %%
type(generator)
# Out:
# keras.src.models.functional.Functional

# %%
generator
# Out:
# <Functional name=functional_32, built=True>

# %%
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=img_shape))
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(256))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()
    img = Input(shape=img_shape)
    validity = model(img)
    return Model(img, validity)

# %%
discriminator = build_discriminator()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_2 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_9 (LeakyReLU)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 533,505 (2.04 MB)
#  Trainable params: 533,505 (2.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
discriminator
# Out:
# <Functional name=functional_39, built=True>

# %%
def train(epochs, batch_size=128, save_interval=50):
    
    (X_train, _), (_, _) = mnist.load_data()
    # Convert to float and Rescale -1 to 1 (Can also do 0 to 1)
    X_train = (X_train.astype(np.float32) - 127.5) / 127.5

    #Add channels dimension. As the input to our gen and discr. has a shape 28x28x1.
    X_train = np.expand_dims(X_train, axis=3) 
    half_batch = int(batch_size / 2)
    
    for epoch in range(epochs):

        # ---------------------
        #  Train Discriminator
        # ---------------------
        idx = np.random.randint(0, X_train.shape[0], half_batch)
        imgs = X_train[idx]
        noise = np.random.normal(0, 1, (half_batch, 100))
        
        # Generate a half batch of fake images
        gen_imgs = generator.predict(noise)

        # Train the discriminator on real and fake images, separately
        #Research showed that separate training is more effective. 
        d_loss_real = discriminator.train_on_batch(imgs, np.ones((half_batch, 1)))
        d_loss_fake = discriminator.train_on_batch(gen_imgs, np.zeros((half_batch, 1)))
        #take average loss from real and fake images. 
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) 

        #And within the same loop we train our Generator, by setting the input noise and
        #ultimately training the Generator to have the Discriminator label its samples as valid
        #by specifying the gradient loss.
        # ---------------------
        #  Train Generator
        # ---------------------
        #Create noise vectors as input for generator. 
        #Create as many noise vectors as defined by the batch size. 
        #Based on normal distribution. Output will be of size (batch size, 100)
        noise = np.random.normal(0, 1, (batch_size, 100)) 

        # The generator wants the discriminator to label the generated samples
        # as valid (ones)
        #This is where the genrator is trying to trick discriminator into believing
        #the generated image is true (hence value of 1 for y)
        valid_y = np.array([1] * batch_size) #Creates an array of all ones of size=batch size

        # Generator is part of combined where it got directly linked with the discriminator
        # Train the generator with noise as x and 1 as y. 
        # Again, 1 as the output as it is adversarial and if generator did a great
        #job of folling the discriminator then the output would be 1 (true)
        g_loss = combined.train_on_batch(noise, valid_y)


        #Additionally, in order for us to keep track of our training process, we print the
        #progress and save the sample image output depending on the epoch interval specified.  
        # Plot the progress
        
        print ("epoch = {},d_loss = {},100*d_loss = {},g_loss = {}".format(epoch, d_loss[0], 100*d_loss[1], g_loss))

        # If at save interval => save generated image samples
        if epoch % save_interval == 0:
            save_imgs(epoch)

# %%
def save_imgs(epoch):
    r, c = 5, 5
    noise = np.random.normal(0, 1, (r * c, 100))
    gen_imgs = generator.predict(noise)
    # Rescale images 0 - 1
    gen_imgs = 0.5 * gen_imgs + 0.5

    fig, axs = plt.subplots(r, c)
    cnt = 0
    for i in range(r):
        for j in range(c):
            axs[i,j].imshow(gen_imgs[cnt, :,:,0], cmap='gray')
            axs[i,j].axis('off')
            cnt += 1
    fig.savefig("images/mnist_%d.png" % epoch)
    plt.close()

# %%
optimizer = Adam(0.0002, 0.5)  #Learning rate and momentum.

discriminator = build_discriminator()
discriminator.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

generator = build_generator()
generator.compile(loss='binary_crossentropy', optimizer=optimizer)

z = Input(shape=(100,))
img = generator(z)

discriminator.trainable = False  
valid = discriminator(img)

combined = Model(z, valid)
combined.compile(loss='binary_crossentropy', optimizer=optimizer)

train(epochs=10000, batch_size=32, save_interval=100)

generator.save('generator_model.h5')
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_5 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_20 (LeakyReLU)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_21 (LeakyReLU)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 533,505 (2.04 MB)
#  Trainable params: 533,505 (2.04 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_32 (Dense)                │ (None, 256)            │        25,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_22 (LeakyReLU)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_23 (LeakyReLU)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 1024)           │       525,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_24 (LeakyReLU)      │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 784)            │       803,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_5 (Reshape)             │ (None, 28, 28, 1)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,493,520 (5.70 MB)
#  Trainable params: 1,489,936 (5.68 MB)
#  Non-trainable params: 3,584 (14.00 KB)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# epoch = 0,d_loss = 0.9832408428192139,100*d_loss = 20.3125,g_loss = [array(0.87679976, dtype=float32), array(0.87679976, dtype=float32), array(0.87679976, dtype=float32), array(0.40625, dtype=float32)]
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x16a4fdda0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch = 1,d_loss = 0.9271963834762573,100*d_loss = 30.98958134651184,g_loss = [array(0.896206, dtype=float32), array(0.896206, dtype=float32), array(0.896206, dtype=float32), array(0.328125, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 2,d_loss = 0.9001444578170776,100*d_loss = 26.666665077209473,g_loss = [array(0.8833422, dtype=float32), array(0.8833422, dtype=float32), array(0.8833422, dtype=float32), array(0.27083334, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 3,d_loss = 0.8917641639709473,100*d_loss = 24.609375,g_loss = [array(0.88630307, dtype=float32), array(0.88630307, dtype=float32), array(0.88630307, dtype=float32), array(0.2421875, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 4,d_loss = 0.8968715667724609,100*d_loss = 22.361111640930176,g_loss = [array(0.89176303, dtype=float32), array(0.89176303, dtype=float32), array(0.89176303, dtype=float32), array(0.225, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 5,d_loss = 0.8979058265686035,100*d_loss = 20.643939077854156,g_loss = [array(0.8935366, dtype=float32), array(0.8935366, dtype=float32), array(0.8935366, dtype=float32), array(0.20833333, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 6,d_loss = 0.911095380783081,100*d_loss = 19.0075546503067,g_loss = [array(0.9125558, dtype=float32), array(0.9125558, dtype=float32), array(0.9125558, dtype=float32), array(0.18303572, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 7,d_loss = 0.9212913513183594,100*d_loss = 16.953125596046448,g_loss = [array(0.9241643, dtype=float32), array(0.9241643, dtype=float32), array(0.9241643, dtype=float32), array(0.1640625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 8,d_loss = 0.9311909675598145,100*d_loss = 15.727123618125916,g_loss = [array(0.9339626, dtype=float32), array(0.9339626, dtype=float32), array(0.9339626, dtype=float32), array(0.15277778, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 9,d_loss = 0.9419969916343689,100*d_loss = 14.424341917037964,g_loss = [array(0.94416934, dtype=float32), array(0.94416934, dtype=float32), array(0.94416934, dtype=float32), array(0.14375, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 10,d_loss = 0.9547839164733887,100*d_loss = 13.379329442977905,g_loss = [array(0.9598372, dtype=float32), array(0.9598372, dtype=float32), array(0.9598372, dtype=float32), array(0.13068181, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 11,d_loss = 0.9656182527542114,100*d_loss = 12.901946902275085,g_loss = [array(0.96916914, dtype=float32), array(0.96916914, dtype=float32), array(0.96916914, dtype=float32), array(0.12760417, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 12,d_loss = 0.9731581211090088,100*d_loss = 12.25961521267891,g_loss = [array(0.9765583, dtype=float32), array(0.9765583, dtype=float32), array(0.9765583, dtype=float32), array(0.1201923, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 13,d_loss = 0.979995846748352,100*d_loss = 12.049438059329987,g_loss = [array(0.98281956, dtype=float32), array(0.98281956, dtype=float32), array(0.98281956, dtype=float32), array(0.11830357, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 14,d_loss = 0.98895263671875,100*d_loss = 11.443965137004852,g_loss = [array(0.99412733, dtype=float32), array(0.99412733, dtype=float32), array(0.99412733, dtype=float32), array(0.1125, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 15,d_loss = 0.9946651458740234,100*d_loss = 11.806955933570862,g_loss = [array(0.9976881, dtype=float32), array(0.9976881, dtype=float32), array(0.9976881, dtype=float32), array(0.1171875, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 16,d_loss = 1.0028225183486938,100*d_loss = 11.47504448890686,g_loss = [array(1.0063255, dtype=float32), array(1.0063255, dtype=float32), array(1.0063255, dtype=float32), array(0.11397059, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 17,d_loss = 1.011152744293213,100*d_loss = 11.44593209028244,g_loss = [array(1.0163271, dtype=float32), array(1.0163271, dtype=float32), array(1.0163271, dtype=float32), array(0.11284722, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 18,d_loss = 1.0185444355010986,100*d_loss = 11.168652027845383,g_loss = [array(1.0226208, dtype=float32), array(1.0226208, dtype=float32), array(1.0226208, dtype=float32), array(0.11019737, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 19,d_loss = 1.0239007472991943,100*d_loss = 11.235977709293365,g_loss = [array(1.0272052, dtype=float32), array(1.0272052, dtype=float32), array(1.0272052, dtype=float32), array(0.1109375, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 20,d_loss = 1.0293338298797607,100*d_loss = 10.995572060346603,g_loss = [array(1.0335355, dtype=float32), array(1.0335355, dtype=float32), array(1.0335355, dtype=float32), array(0.10863096, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 21,d_loss = 1.0339587926864624,100*d_loss = 10.92098355293274,g_loss = [array(1.0365325, dtype=float32), array(1.0365325, dtype=float32), array(1.0365325, dtype=float32), array(0.10795455, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 22,d_loss = 1.0382142066955566,100*d_loss = 10.715579986572266,g_loss = [array(1.0415189, dtype=float32), array(1.0415189, dtype=float32), array(1.0415189, dtype=float32), array(0.10597826, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 23,d_loss = 1.0461081266403198,100*d_loss = 10.527482628822327,g_loss = [array(1.0501899, dtype=float32), array(1.0501899, dtype=float32), array(1.0501899, dtype=float32), array(0.10416666, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 24,d_loss = 1.0513358116149902,100*d_loss = 10.35459190607071,g_loss = [array(1.0549204, dtype=float32), array(1.0549204, dtype=float32), array(1.0549204, dtype=float32), array(0.1025, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 25,d_loss = 1.0602447986602783,100*d_loss = 10.073764622211456,g_loss = [array(1.0660174, dtype=float32), array(1.0660174, dtype=float32), array(1.0660174, dtype=float32), array(0.09975962, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 26,d_loss = 1.0682768821716309,100*d_loss = 9.813941270112991,g_loss = [array(1.0720667, dtype=float32), array(1.0720667, dtype=float32), array(1.0720667, dtype=float32), array(0.09722222, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 27,d_loss = 1.0774261951446533,100*d_loss = 9.572848677635193,g_loss = [array(1.0843579, dtype=float32), array(1.0843579, dtype=float32), array(1.0843579, dtype=float32), array(0.09486607, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 28,d_loss = 1.0898597240447998,100*d_loss = 9.457236528396606,g_loss = [array(1.0960469, dtype=float32), array(1.0960469, dtype=float32), array(1.0960469, dtype=float32), array(0.09375, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 29,d_loss = 1.1012725830078125,100*d_loss = 9.34939980506897,g_loss = [array(1.1068473, dtype=float32), array(1.1068473, dtype=float32), array(1.1068473, dtype=float32), array(0.09270833, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 30,d_loss = 1.1098520755767822,100*d_loss = 9.248578548431396,g_loss = [array(1.1143032, dtype=float32), array(1.1143032, dtype=float32), array(1.1143032, dtype=float32), array(0.09173387, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 31,d_loss = 1.118436336517334,100*d_loss = 9.0556800365448,g_loss = [array(1.1244634, dtype=float32), array(1.1244634, dtype=float32), array(1.1244634, dtype=float32), array(0.08984375, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 32,d_loss = 1.1286182403564453,100*d_loss = 8.874562382698059,g_loss = [array(1.1338235, dtype=float32), array(1.1338235, dtype=float32), array(1.1338235, dtype=float32), array(0.08806818, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 33,d_loss = 1.1375449895858765,100*d_loss = 8.889377117156982,g_loss = [array(1.1436981, dtype=float32), array(1.1436981, dtype=float32), array(1.1436981, dtype=float32), array(0.0882353, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 34,d_loss = 1.1468878984451294,100*d_loss = 8.72347354888916,g_loss = [array(1.1522667, dtype=float32), array(1.1522667, dtype=float32), array(1.1522667, dtype=float32), array(0.08660714, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 35,d_loss = 1.1557542085647583,100*d_loss = 8.566852658987045,g_loss = [array(1.1614386, dtype=float32), array(1.1614386, dtype=float32), array(1.1614386, dtype=float32), array(0.08506945, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 36,d_loss = 1.164963960647583,100*d_loss = 8.50379467010498,g_loss = [array(1.1697136, dtype=float32), array(1.1697136, dtype=float32), array(1.1697136, dtype=float32), array(0.08445946, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 37,d_loss = 1.1722474098205566,100*d_loss = 8.444079011678696,g_loss = [array(1.177017, dtype=float32), array(1.177017, dtype=float32), array(1.177017, dtype=float32), array(0.08388158, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 38,d_loss = 1.180118441581726,100*d_loss = 8.306796848773956,g_loss = [array(1.1850054, dtype=float32), array(1.1850054, dtype=float32), array(1.1850054, dtype=float32), array(0.08253205, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 39,d_loss = 1.1864674091339111,100*d_loss = 8.255043625831604,g_loss = [array(1.191325, dtype=float32), array(1.191325, dtype=float32), array(1.191325, dtype=float32), array(0.08203125, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 40,d_loss = 1.1931118965148926,100*d_loss = 8.205830305814743,g_loss = [array(1.1987457, dtype=float32), array(1.1987457, dtype=float32), array(1.1987457, dtype=float32), array(0.08155487, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 41,d_loss = 1.2013076543807983,100*d_loss = 8.158975839614868,g_loss = [array(1.206683, dtype=float32), array(1.206683, dtype=float32), array(1.206683, dtype=float32), array(0.08110119, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 42,d_loss = 1.2096025943756104,100*d_loss = 8.187414705753326,g_loss = [array(1.2149806, dtype=float32), array(1.2149806, dtype=float32), array(1.2149806, dtype=float32), array(0.08139535, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 43,d_loss = 1.2195196151733398,100*d_loss = 8.071692287921906,g_loss = [array(1.2253116, dtype=float32), array(1.2253116, dtype=float32), array(1.2253116, dtype=float32), array(0.08025568, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 44,d_loss = 1.2279024124145508,100*d_loss = 8.030977100133896,g_loss = [array(1.2329868, dtype=float32), array(1.2329868, dtype=float32), array(1.2329868, dtype=float32), array(0.07986111, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 45,d_loss = 1.2354837656021118,100*d_loss = 7.855425775051117,g_loss = [array(1.2399876, dtype=float32), array(1.2399876, dtype=float32), array(1.2399876, dtype=float32), array(0.078125, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 46,d_loss = 1.242897391319275,100*d_loss = 7.821079343557358,g_loss = [array(1.2481698, dtype=float32), array(1.2481698, dtype=float32), array(1.2481698, dtype=float32), array(0.07779256, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 47,d_loss = 1.2510218620300293,100*d_loss = 7.9190656542778015,g_loss = [array(1.2564889, dtype=float32), array(1.2564889, dtype=float32), array(1.2564889, dtype=float32), array(0.07877604, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 48,d_loss = 1.2606465816497803,100*d_loss = 7.820717990398407,g_loss = [array(1.266069, dtype=float32), array(1.266069, dtype=float32), array(1.266069, dtype=float32), array(0.07780612, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 49,d_loss = 1.2681498527526855,100*d_loss = 7.851956784725189,g_loss = [array(1.2731066, dtype=float32), array(1.2731066, dtype=float32), array(1.2731066, dtype=float32), array(0.078125, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 50,d_loss = 1.276153802871704,100*d_loss = 7.758808881044388,g_loss = [array(1.2808313, dtype=float32), array(1.2808313, dtype=float32), array(1.2808313, dtype=float32), array(0.07720588, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 51,d_loss = 1.283445119857788,100*d_loss = 7.729649543762207,g_loss = [array(1.2892957, dtype=float32), array(1.2892957, dtype=float32), array(1.2892957, dtype=float32), array(0.07692308, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 52,d_loss = 1.2919325828552246,100*d_loss = 7.64235183596611,g_loss = [array(1.2972522, dtype=float32), array(1.2972522, dtype=float32), array(1.2972522, dtype=float32), array(0.07606132, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 53,d_loss = 1.3004677295684814,100*d_loss = 7.558303326368332,g_loss = [array(1.3062742, dtype=float32), array(1.3062742, dtype=float32), array(1.3062742, dtype=float32), array(0.07523149, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 54,d_loss = 1.3084934949874878,100*d_loss = 7.534404098987579,g_loss = [array(1.3136148, dtype=float32), array(1.3136148, dtype=float32), array(1.3136148, dtype=float32), array(0.075, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 55,d_loss = 1.3174552917480469,100*d_loss = 7.455307245254517,g_loss = [array(1.3232888, dtype=float32), array(1.3232888, dtype=float32), array(1.3232888, dtype=float32), array(0.07421875, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 56,d_loss = 1.3251607418060303,100*d_loss = 7.323930412530899,g_loss = [array(1.3297564, dtype=float32), array(1.3297564, dtype=float32), array(1.3297564, dtype=float32), array(0.07291666, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 57,d_loss = 1.332289218902588,100*d_loss = 7.25121796131134,g_loss = [array(1.3366793, dtype=float32), array(1.3366793, dtype=float32), array(1.3366793, dtype=float32), array(0.07219828, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 58,d_loss = 1.3379732370376587,100*d_loss = 7.180981338024139,g_loss = [array(1.342133, dtype=float32), array(1.342133, dtype=float32), array(1.342133, dtype=float32), array(0.07150424, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 59,d_loss = 1.344269037246704,100*d_loss = 7.1653977036476135,g_loss = [array(1.3495594, dtype=float32), array(1.3495594, dtype=float32), array(1.3495594, dtype=float32), array(0.07135417, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 60,d_loss = 1.3519458770751953,100*d_loss = 7.098885625600815,g_loss = [array(1.356936, dtype=float32), array(1.356936, dtype=float32), array(1.356936, dtype=float32), array(0.07069672, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 61,d_loss = 1.359351396560669,100*d_loss = 7.0345282554626465,g_loss = [array(1.3641305, dtype=float32), array(1.3641305, dtype=float32), array(1.3641305, dtype=float32), array(0.07006048, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 62,d_loss = 1.366774320602417,100*d_loss = 6.922420859336853,g_loss = [array(1.3722527, dtype=float32), array(1.3722527, dtype=float32), array(1.3722527, dtype=float32), array(0.06894841, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 63,d_loss = 1.3743069171905518,100*d_loss = 6.862850487232208,g_loss = [array(1.3797503, dtype=float32), array(1.3797503, dtype=float32), array(1.3797503, dtype=float32), array(0.06835938, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 64,d_loss = 1.3828277587890625,100*d_loss = 6.75685778260231,g_loss = [array(1.3878013, dtype=float32), array(1.3878013, dtype=float32), array(1.3878013, dtype=float32), array(0.0673077, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 65,d_loss = 1.3898961544036865,100*d_loss = 6.701618432998657,g_loss = [array(1.3951129, dtype=float32), array(1.3951129, dtype=float32), array(1.3951129, dtype=float32), array(0.06676137, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 66,d_loss = 1.3964905738830566,100*d_loss = 6.694850325584412,g_loss = [array(1.4014066, dtype=float32), array(1.4014066, dtype=float32), array(1.4014066, dtype=float32), array(0.06669776, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 67,d_loss = 1.4034154415130615,100*d_loss = 6.6421568393707275,g_loss = [array(1.4081507, dtype=float32), array(1.4081507, dtype=float32), array(1.4081507, dtype=float32), array(0.06617647, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 68,d_loss = 1.4103257656097412,100*d_loss = 6.59099668264389,g_loss = [array(1.4157186, dtype=float32), array(1.4157186, dtype=float32), array(1.4157186, dtype=float32), array(0.06567029, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 69,d_loss = 1.4169766902923584,100*d_loss = 6.630909442901611,g_loss = [array(1.4216392, dtype=float32), array(1.4216392, dtype=float32), array(1.4216392, dtype=float32), array(0.06607143, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 70,d_loss = 1.424303412437439,100*d_loss = 6.625524163246155,g_loss = [array(1.4301962, dtype=float32), array(1.4301962, dtype=float32), array(1.4301962, dtype=float32), array(0.06602113, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 71,d_loss = 1.4322302341461182,100*d_loss = 6.5331801772117615,g_loss = [array(1.4369864, dtype=float32), array(1.4369864, dtype=float32), array(1.4369864, dtype=float32), array(0.06510416, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 72,d_loss = 1.4388957023620605,100*d_loss = 6.572242826223373,g_loss = [array(1.444007, dtype=float32), array(1.444007, dtype=float32), array(1.444007, dtype=float32), array(0.06549658, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 73,d_loss = 1.445617437362671,100*d_loss = 6.525498628616333,g_loss = [array(1.4501525, dtype=float32), array(1.4501525, dtype=float32), array(1.4501525, dtype=float32), array(0.06503379, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 74,d_loss = 1.4520518779754639,100*d_loss = 6.438198685646057,g_loss = [array(1.4563881, dtype=float32), array(1.4563881, dtype=float32), array(1.4563881, dtype=float32), array(0.06416667, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 75,d_loss = 1.4585943222045898,100*d_loss = 6.3532039523124695,g_loss = [array(1.4629488, dtype=float32), array(1.4629488, dtype=float32), array(1.4629488, dtype=float32), array(0.06332237, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 76,d_loss = 1.465712547302246,100*d_loss = 6.270425021648407,g_loss = [array(1.4708128, dtype=float32), array(1.4708128, dtype=float32), array(1.4708128, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 77,d_loss = 1.4721968173980713,100*d_loss = 6.189774721860886,g_loss = [array(1.4765302, dtype=float32), array(1.4765302, dtype=float32), array(1.4765302, dtype=float32), array(0.06169872, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 78,d_loss = 1.4784440994262695,100*d_loss = 6.230221688747406,g_loss = [array(1.4832122, dtype=float32), array(1.4832122, dtype=float32), array(1.4832122, dtype=float32), array(0.06210443, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 79,d_loss = 1.483914852142334,100*d_loss = 6.3088394701480865,g_loss = [array(1.4881697, dtype=float32), array(1.4881697, dtype=float32), array(1.4881697, dtype=float32), array(0.06289063, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 80,d_loss = 1.4883081912994385,100*d_loss = 6.424210220575333,g_loss = [array(1.491909, dtype=float32), array(1.491909, dtype=float32), array(1.491909, dtype=float32), array(0.06404321, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 81,d_loss = 1.4934132099151611,100*d_loss = 6.383851170539856,g_loss = [array(1.498088, dtype=float32), array(1.498088, dtype=float32), array(1.498088, dtype=float32), array(0.06364329, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 82,d_loss = 1.4996533393859863,100*d_loss = 6.382232904434204,g_loss = [array(1.5041088, dtype=float32), array(1.5041088, dtype=float32), array(1.5041088, dtype=float32), array(0.06362952, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 83,d_loss = 1.5058740377426147,100*d_loss = 6.343340128660202,g_loss = [array(1.5104016, dtype=float32), array(1.5104016, dtype=float32), array(1.5104016, dtype=float32), array(0.06324404, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 84,d_loss = 1.5117461681365967,100*d_loss = 6.342238187789917,g_loss = [array(1.5162725, dtype=float32), array(1.5162725, dtype=float32), array(1.5162725, dtype=float32), array(0.0632353, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 85,d_loss = 1.517504096031189,100*d_loss = 6.341162323951721,g_loss = [array(1.521675, dtype=float32), array(1.521675, dtype=float32), array(1.521675, dtype=float32), array(0.06322674, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 86,d_loss = 1.5229358673095703,100*d_loss = 6.484203040599823,g_loss = [array(1.5282035, dtype=float32), array(1.5282035, dtype=float32), array(1.5282035, dtype=float32), array(0.06465517, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 87,d_loss = 1.5295460224151611,100*d_loss = 6.552759557962418,g_loss = [array(1.533878, dtype=float32), array(1.533878, dtype=float32), array(1.533878, dtype=float32), array(0.06534091, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 88,d_loss = 1.5351256132125854,100*d_loss = 6.61977082490921,g_loss = [array(1.5391908, dtype=float32), array(1.5391908, dtype=float32), array(1.5391908, dtype=float32), array(0.06601124, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 89,d_loss = 1.54038405418396,100*d_loss = 6.615650653839111,g_loss = [array(1.5444853, dtype=float32), array(1.5444853, dtype=float32), array(1.5444853, dtype=float32), array(0.06597222, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 90,d_loss = 1.5454258918762207,100*d_loss = 6.6460564732551575,g_loss = [array(1.5493346, dtype=float32), array(1.5493346, dtype=float32), array(1.5493346, dtype=float32), array(0.06627747, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 91,d_loss = 1.5504237413406372,100*d_loss = 6.675799190998077,g_loss = [array(1.5547961, dtype=float32), array(1.5547961, dtype=float32), array(1.5547961, dtype=float32), array(0.06657609, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 92,d_loss = 1.556755781173706,100*d_loss = 6.637514382600784,g_loss = [array(1.5616393, dtype=float32), array(1.5616393, dtype=float32), array(1.5616393, dtype=float32), array(0.06619623, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 93,d_loss = 1.5630820989608765,100*d_loss = 6.700047850608826,g_loss = [array(1.5677172, dtype=float32), array(1.5677172, dtype=float32), array(1.5677172, dtype=float32), array(0.06682181, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 94,d_loss = 1.569339394569397,100*d_loss = 6.695297360420227,g_loss = [array(1.5738622, dtype=float32), array(1.5738622, dtype=float32), array(1.5738622, dtype=float32), array(0.06677631, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 95,d_loss = 1.575500249862671,100*d_loss = 6.690646708011627,g_loss = [array(1.5802828, dtype=float32), array(1.5802828, dtype=float32), array(1.5802828, dtype=float32), array(0.06673177, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 96,d_loss = 1.5809221267700195,100*d_loss = 6.653791666030884,g_loss = [array(1.5850353, dtype=float32), array(1.5850353, dtype=float32), array(1.5850353, dtype=float32), array(0.06636598, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 97,d_loss = 1.5863978862762451,100*d_loss = 6.585720926523209,g_loss = [array(1.5905539, dtype=float32), array(1.5905539, dtype=float32), array(1.5905539, dtype=float32), array(0.06568877, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 98,d_loss = 1.591970443725586,100*d_loss = 6.519029289484024,g_loss = [array(1.5958973, dtype=float32), array(1.5958973, dtype=float32), array(1.5958973, dtype=float32), array(0.06502526, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 99,d_loss = 1.5975552797317505,100*d_loss = 6.516331434249878,g_loss = [array(1.6020615, dtype=float32), array(1.6020615, dtype=float32), array(1.6020615, dtype=float32), array(0.065, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 100,d_loss = 1.6035367250442505,100*d_loss = 6.482669711112976,g_loss = [array(1.6079316, dtype=float32), array(1.6079316, dtype=float32), array(1.6079316, dtype=float32), array(0.06466584, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 101,d_loss = 1.6089189052581787,100*d_loss = 6.541808694601059,g_loss = [array(1.6134579, dtype=float32), array(1.6134579, dtype=float32), array(1.6134579, dtype=float32), array(0.06525736, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 102,d_loss = 1.6145472526550293,100*d_loss = 6.508554518222809,g_loss = [array(1.6184815, dtype=float32), array(1.6184815, dtype=float32), array(1.6184815, dtype=float32), array(0.06492718, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 103,d_loss = 1.619441270828247,100*d_loss = 6.536182761192322,g_loss = [array(1.6235416, dtype=float32), array(1.6235416, dtype=float32), array(1.6235416, dtype=float32), array(0.06520433, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 104,d_loss = 1.6249066591262817,100*d_loss = 6.53344988822937,g_loss = [array(1.6291015, dtype=float32), array(1.6291015, dtype=float32), array(1.6291015, dtype=float32), array(0.06517857, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 105,d_loss = 1.6301499605178833,100*d_loss = 6.471666693687439,g_loss = [array(1.6340438, dtype=float32), array(1.6340438, dtype=float32), array(1.6340438, dtype=float32), array(0.06456368, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 106,d_loss = 1.6349272727966309,100*d_loss = 6.411042809486389,g_loss = [array(1.6387087, dtype=float32), array(1.6387087, dtype=float32), array(1.6387087, dtype=float32), array(0.06396028, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 107,d_loss = 1.6399520635604858,100*d_loss = 6.380544602870941,g_loss = [array(1.6440717, dtype=float32), array(1.6440717, dtype=float32), array(1.6440717, dtype=float32), array(0.06365741, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 108,d_loss = 1.6458287239074707,100*d_loss = 6.321872770786285,g_loss = [array(1.64999, dtype=float32), array(1.64999, dtype=float32), array(1.64999, dtype=float32), array(0.0630734, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 109,d_loss = 1.651375412940979,100*d_loss = 6.2642693519592285,g_loss = [array(1.6555234, dtype=float32), array(1.6555234, dtype=float32), array(1.6555234, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 110,d_loss = 1.6565682888031006,100*d_loss = 6.264140456914902,g_loss = [array(1.660466, dtype=float32), array(1.660466, dtype=float32), array(1.660466, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 111,d_loss = 1.6611239910125732,100*d_loss = 6.319941580295563,g_loss = [array(1.6651013, dtype=float32), array(1.6651013, dtype=float32), array(1.6651013, dtype=float32), array(0.06305803, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 112,d_loss = 1.6658382415771484,100*d_loss = 6.291605532169342,g_loss = [array(1.6695868, dtype=float32), array(1.6695868, dtype=float32), array(1.6695868, dtype=float32), array(0.06277655, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 113,d_loss = 1.670405626296997,100*d_loss = 6.291238963603973,g_loss = [array(1.674401, dtype=float32), array(1.674401, dtype=float32), array(1.674401, dtype=float32), array(0.06277412, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 114,d_loss = 1.6759510040283203,100*d_loss = 6.263646483421326,g_loss = [array(1.6805704, dtype=float32), array(1.6805704, dtype=float32), array(1.6805704, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 115,d_loss = 1.6814327239990234,100*d_loss = 6.263528019189835,g_loss = [array(1.6857157, dtype=float32), array(1.6857157, dtype=float32), array(1.6857157, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 116,d_loss = 1.6878091096878052,100*d_loss = 6.209878623485565,g_loss = [array(1.6921201, dtype=float32), array(1.6921201, dtype=float32), array(1.6921201, dtype=float32), array(0.06196581, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 117,d_loss = 1.6923600435256958,100*d_loss = 6.26329779624939,g_loss = [array(1.6961122, dtype=float32), array(1.6961122, dtype=float32), array(1.6961122, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 118,d_loss = 1.6970701217651367,100*d_loss = 6.2105536460876465,g_loss = [array(1.7004955, dtype=float32), array(1.7004955, dtype=float32), array(1.7004955, dtype=float32), array(0.06197479, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 119,d_loss = 1.7013648748397827,100*d_loss = 6.2108829617500305,g_loss = [array(1.7052066, dtype=float32), array(1.7052066, dtype=float32), array(1.7052066, dtype=float32), array(0.06197917, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 120,d_loss = 1.7059681415557861,100*d_loss = 6.185326725244522,g_loss = [array(1.7096199, dtype=float32), array(1.7096199, dtype=float32), array(1.7096199, dtype=float32), array(0.06172521, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 121,d_loss = 1.7112420797348022,100*d_loss = 6.16019032895565,g_loss = [array(1.715728, dtype=float32), array(1.715728, dtype=float32), array(1.715728, dtype=float32), array(0.06147541, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 122,d_loss = 1.7166070938110352,100*d_loss = 6.1354633420705795,g_loss = [array(1.7202555, dtype=float32), array(1.7202555, dtype=float32), array(1.7202555, dtype=float32), array(0.06122968, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 123,d_loss = 1.7218332290649414,100*d_loss = 6.1363887041807175,g_loss = [array(1.7257859, dtype=float32), array(1.7257859, dtype=float32), array(1.7257859, dtype=float32), array(0.06123992, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 124,d_loss = 1.7268202304840088,100*d_loss = 6.137299165129662,g_loss = [array(1.7308214, dtype=float32), array(1.7308214, dtype=float32), array(1.7308214, dtype=float32), array(0.06125, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 125,d_loss = 1.7321606874465942,100*d_loss = 6.113344430923462,g_loss = [array(1.7362291, dtype=float32), array(1.7362291, dtype=float32), array(1.7362291, dtype=float32), array(0.0610119, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 126,d_loss = 1.7371137142181396,100*d_loss = 6.163731962442398,g_loss = [array(1.7409681, dtype=float32), array(1.7409681, dtype=float32), array(1.7409681, dtype=float32), array(0.06151575, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 127,d_loss = 1.7421399354934692,100*d_loss = 6.21333122253418,g_loss = [array(1.7463323, dtype=float32), array(1.7463323, dtype=float32), array(1.7463323, dtype=float32), array(0.06201172, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 128,d_loss = 1.7469866275787354,100*d_loss = 6.189343705773354,g_loss = [array(1.7505769, dtype=float32), array(1.7505769, dtype=float32), array(1.7505769, dtype=float32), array(0.06177326, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 129,d_loss = 1.751659631729126,100*d_loss = 6.2379807233810425,g_loss = [array(1.7557223, dtype=float32), array(1.7557223, dtype=float32), array(1.7557223, dtype=float32), array(0.06225961, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 130,d_loss = 1.7563457489013672,100*d_loss = 6.238072365522385,g_loss = [array(1.7598858, dtype=float32), array(1.7598858, dtype=float32), array(1.7598858, dtype=float32), array(0.06226145, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 131,d_loss = 1.7613177299499512,100*d_loss = 6.190724670886993,g_loss = [array(1.7651867, dtype=float32), array(1.7651867, dtype=float32), array(1.7651867, dtype=float32), array(0.06178977, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 132,d_loss = 1.7666115760803223,100*d_loss = 6.191170960664749,g_loss = [array(1.7710255, dtype=float32), array(1.7710255, dtype=float32), array(1.7710255, dtype=float32), array(0.06179511, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 133,d_loss = 1.7718260288238525,100*d_loss = 6.214974820613861,g_loss = [array(1.7755651, dtype=float32), array(1.7755651, dtype=float32), array(1.7755651, dtype=float32), array(0.06203358, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 134,d_loss = 1.7765719890594482,100*d_loss = 6.215234845876694,g_loss = [array(1.7802254, dtype=float32), array(1.7802254, dtype=float32), array(1.7802254, dtype=float32), array(0.06203704, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 135,d_loss = 1.7808630466461182,100*d_loss = 6.215490400791168,g_loss = [array(1.7844402, dtype=float32), array(1.7844402, dtype=float32), array(1.7844402, dtype=float32), array(0.06204044, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 136,d_loss = 1.7854602336883545,100*d_loss = 6.215742975473404,g_loss = [array(1.7894597, dtype=float32), array(1.7894597, dtype=float32), array(1.7894597, dtype=float32), array(0.0620438, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 137,d_loss = 1.7900221347808838,100*d_loss = 6.193305552005768,g_loss = [array(1.7933142, dtype=float32), array(1.7933142, dtype=float32), array(1.7933142, dtype=float32), array(0.06182065, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 138,d_loss = 1.794677972793579,100*d_loss = 6.171191111207008,g_loss = [array(1.7988122, dtype=float32), array(1.7988122, dtype=float32), array(1.7988122, dtype=float32), array(0.06160072, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 139,d_loss = 1.7992711067199707,100*d_loss = 6.171754747629166,g_loss = [array(1.8026067, dtype=float32), array(1.8026067, dtype=float32), array(1.8026067, dtype=float32), array(0.06160714, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 140,d_loss = 1.803817629814148,100*d_loss = 6.172310560941696,g_loss = [array(1.8076903, dtype=float32), array(1.8076903, dtype=float32), array(1.8076903, dtype=float32), array(0.06161347, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 141,d_loss = 1.8090394735336304,100*d_loss = 6.150812655687332,g_loss = [array(1.8127578, dtype=float32), array(1.8127578, dtype=float32), array(1.8127578, dtype=float32), array(0.06139965, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 142,d_loss = 1.8131109476089478,100*d_loss = 6.195290386676788,g_loss = [array(1.8166353, dtype=float32), array(1.8166353, dtype=float32), array(1.8166353, dtype=float32), array(0.0618444, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 143,d_loss = 1.817256212234497,100*d_loss = 6.2174104154109955,g_loss = [array(1.8209084, dtype=float32), array(1.8209084, dtype=float32), array(1.8209084, dtype=float32), array(0.06206597, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 144,d_loss = 1.8215616941452026,100*d_loss = 6.239224225282669,g_loss = [array(1.8253163, dtype=float32), array(1.8253163, dtype=float32), array(1.8253163, dtype=float32), array(0.06228448, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 145,d_loss = 1.8257901668548584,100*d_loss = 6.217857077717781,g_loss = [array(1.8293401, dtype=float32), array(1.8293401, dtype=float32), array(1.8293401, dtype=float32), array(0.06207192, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 146,d_loss = 1.8298263549804688,100*d_loss = 6.2819600105285645,g_loss = [array(1.8333191, dtype=float32), array(1.8333191, dtype=float32), array(1.8333191, dtype=float32), array(0.06271259, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 147,d_loss = 1.8344433307647705,100*d_loss = 6.281743943691254,g_loss = [array(1.8385715, dtype=float32), array(1.8385715, dtype=float32), array(1.8385715, dtype=float32), array(0.06271115, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 148,d_loss = 1.8389949798583984,100*d_loss = 6.260521709918976,g_loss = [array(1.8423083, dtype=float32), array(1.8423083, dtype=float32), array(1.8423083, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 149,d_loss = 1.8435370922088623,100*d_loss = 6.218715012073517,g_loss = [array(1.8476062, dtype=float32), array(1.8476062, dtype=float32), array(1.8476062, dtype=float32), array(0.06208333, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 150,d_loss = 1.8482933044433594,100*d_loss = 6.239652261137962,g_loss = [array(1.8519404, dtype=float32), array(1.8519404, dtype=float32), array(1.8519404, dtype=float32), array(0.06229305, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 151,d_loss = 1.8525593280792236,100*d_loss = 6.198533996939659,g_loss = [array(1.8559835, dtype=float32), array(1.8559835, dtype=float32), array(1.8559835, dtype=float32), array(0.06188322, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 152,d_loss = 1.8564153909683228,100*d_loss = 6.178412586450577,g_loss = [array(1.8598568, dtype=float32), array(1.8598568, dtype=float32), array(1.8598568, dtype=float32), array(0.06168301, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 153,d_loss = 1.8611764907836914,100*d_loss = 6.158553063869476,g_loss = [array(1.865208, dtype=float32), array(1.865208, dtype=float32), array(1.865208, dtype=float32), array(0.06148539, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 154,d_loss = 1.865678071975708,100*d_loss = 6.179337576031685,g_loss = [array(1.8691394, dtype=float32), array(1.8691394, dtype=float32), array(1.8691394, dtype=float32), array(0.06169355, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# epoch = 155,d_loss = 1.869775414466858,100*d_loss = 6.199855357408524,g_loss = [array(1.8735831, dtype=float32), array(1.8735831, dtype=float32), array(1.8735831, dtype=float32), array(0.06189904, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 156,d_loss = 1.8741952180862427,100*d_loss = 6.200174987316132,g_loss = [array(1.8775942, dtype=float32), array(1.8775942, dtype=float32), array(1.8775942, dtype=float32), array(0.06190287, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch = 157,d_loss = 1.8781559467315674,100*d_loss = 6.220300868153572,g_loss = [array(1.8816447, dtype=float32), array(1.8816447, dtype=float32), array(1.8816447, dtype=float32), array(0.06210443, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 158,d_loss = 1.8824882507324219,100*d_loss = 6.25985786318779,g_loss = [array(1.8862191, dtype=float32), array(1.8862191, dtype=float32), array(1.8862191, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 159,d_loss = 1.886932611465454,100*d_loss = 6.2597960233688354,g_loss = [array(1.890547, dtype=float32), array(1.890547, dtype=float32), array(1.890547, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 160,d_loss = 1.8911852836608887,100*d_loss = 6.279174983501434,g_loss = [array(1.8945913, dtype=float32), array(1.8945913, dtype=float32), array(1.8945913, dtype=float32), array(0.0626941, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 161,d_loss = 1.8956298828125,100*d_loss = 6.278994679450989,g_loss = [array(1.8992451, dtype=float32), array(1.8992451, dtype=float32), array(1.8992451, dtype=float32), array(0.0626929, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 162,d_loss = 1.899420976638794,100*d_loss = 6.298017501831055,g_loss = [array(1.9027107, dtype=float32), array(1.9027107, dtype=float32), array(1.9027107, dtype=float32), array(0.06288344, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 163,d_loss = 1.9031956195831299,100*d_loss = 6.297724694013596,g_loss = [array(1.9065058, dtype=float32), array(1.9065058, dtype=float32), array(1.9065058, dtype=float32), array(0.0628811, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 164,d_loss = 1.9072160720825195,100*d_loss = 6.2594980001449585,g_loss = [array(1.9104748, dtype=float32), array(1.9104748, dtype=float32), array(1.9104748, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 165,d_loss = 1.9113620519638062,100*d_loss = 6.2217336148023605,g_loss = [array(1.9147111, dtype=float32), array(1.9147111, dtype=float32), array(1.9147111, dtype=float32), array(0.06212349, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 166,d_loss = 1.9150986671447754,100*d_loss = 6.2219031155109406,g_loss = [array(1.9183267, dtype=float32), array(1.9183267, dtype=float32), array(1.9183267, dtype=float32), array(0.06212575, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 167,d_loss = 1.9184610843658447,100*d_loss = 6.203441321849823,g_loss = [array(1.9215515, dtype=float32), array(1.9215515, dtype=float32), array(1.9215515, dtype=float32), array(0.06194196, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 168,d_loss = 1.922691822052002,100*d_loss = 6.203717365860939,g_loss = [array(1.9265127, dtype=float32), array(1.9265127, dtype=float32), array(1.9265127, dtype=float32), array(0.06194527, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 169,d_loss = 1.927567481994629,100*d_loss = 6.222399324178696,g_loss = [array(1.9312294, dtype=float32), array(1.9312294, dtype=float32), array(1.9312294, dtype=float32), array(0.06213235, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 170,d_loss = 1.9311256408691406,100*d_loss = 6.259164214134216,g_loss = [array(1.9340954, dtype=float32), array(1.9340954, dtype=float32), array(1.9340954, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 171,d_loss = 1.9352895021438599,100*d_loss = 6.2591105699539185,g_loss = [array(1.9391215, dtype=float32), array(1.9391215, dtype=float32), array(1.9391215, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 172,d_loss = 1.939518690109253,100*d_loss = 6.25905841588974,g_loss = [array(1.9427482, dtype=float32), array(1.9427482, dtype=float32), array(1.9427482, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# epoch = 173,d_loss = 1.9430725574493408,100*d_loss = 6.2590062618255615,g_loss = [array(1.9460992, dtype=float32), array(1.9460992, dtype=float32), array(1.9460992, dtype=float32), array(0.0625, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5353,d_loss = 4.487992286682129,100*d_loss = 5.520663037896156,g_loss = [array(4.488232, dtype=float32), array(4.488232, dtype=float32), array(4.488232, dtype=float32), array(0.05520405, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch = 5354,d_loss = 4.4881486892700195,100*d_loss = 5.52079938352108,g_loss = [array(4.4883966, dtype=float32), array(4.4883966, dtype=float32), array(4.4883966, dtype=float32), array(0.05520542, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch = 5355,d_loss = 4.488312721252441,100*d_loss = 5.520351976156235,g_loss = [array(4.4885583, dtype=float32), array(4.4885583, dtype=float32), array(4.4885583, dtype=float32), array(0.05520094, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5356,d_loss = 4.488471031188965,100*d_loss = 5.519904941320419,g_loss = [array(4.4887156, dtype=float32), array(4.4887156, dtype=float32), array(4.4887156, dtype=float32), array(0.05519647, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5357,d_loss = 4.4886274337768555,100*d_loss = 5.522957444190979,g_loss = [array(4.4888744, dtype=float32), array(4.4888744, dtype=float32), array(4.4888744, dtype=float32), array(0.055227, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5358,d_loss = 4.488786697387695,100*d_loss = 5.522509664297104,g_loss = [array(4.489028, dtype=float32), array(4.489028, dtype=float32), array(4.489028, dtype=float32), array(0.05522252, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5359,d_loss = 4.488954067230225,100*d_loss = 5.522646009922028,g_loss = [array(4.4892063, dtype=float32), array(4.4892063, dtype=float32), array(4.4892063, dtype=float32), array(0.05522388, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5360,d_loss = 4.489128112792969,100*d_loss = 5.523364245891571,g_loss = [array(4.4893756, dtype=float32), array(4.4893756, dtype=float32), array(4.4893756, dtype=float32), array(0.05523107, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch = 5361,d_loss = 4.489316463470459,100*d_loss = 5.522334203124046,g_loss = [array(4.4895706, dtype=float32), array(4.4895706, dtype=float32), array(4.4895706, dtype=float32), array(0.05522077, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5362,d_loss = 4.489479064941406,100*d_loss = 5.523635447025299,g_loss = [array(4.489722, dtype=float32), array(4.489722, dtype=float32), array(4.489722, dtype=float32), array(0.05523378, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5363,d_loss = 4.48963737487793,100*d_loss = 5.523770675063133,g_loss = [array(4.4898806, dtype=float32), array(4.4898806, dtype=float32), array(4.4898806, dtype=float32), array(0.05523513, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch = 5364,d_loss = 4.489798545837402,100*d_loss = 5.523323640227318,g_loss = [array(4.490046, dtype=float32), array(4.490046, dtype=float32), array(4.490046, dtype=float32), array(0.05523066, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch = 5365,d_loss = 4.48996639251709,100*d_loss = 5.524041503667831,g_loss = [array(4.4902134, dtype=float32), array(4.4902134, dtype=float32), array(4.4902134, dtype=float32), array(0.05523784, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5366,d_loss = 4.490139007568359,100*d_loss = 5.524176731705666,g_loss = [array(4.490386, dtype=float32), array(4.490386, dtype=float32), array(4.490386, dtype=float32), array(0.05523919, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5367,d_loss = 4.4903178215026855,100*d_loss = 5.523147433996201,g_loss = [array(4.490567, dtype=float32), array(4.490567, dtype=float32), array(4.490567, dtype=float32), array(0.0552289, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 5368,d_loss = 4.490495681762695,100*d_loss = 5.522118508815765,g_loss = [array(4.4907413, dtype=float32), array(4.4907413, dtype=float32), array(4.4907413, dtype=float32), array(0.05521861, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch = 5369,d_loss = 4.490664482116699,100*d_loss = 5.52167221903801,g_loss = [array(4.490906, dtype=float32), array(4.490906, dtype=float32), array(4.490906, dtype=float32), array(0.05521415, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5370,d_loss = 4.490824222564697,100*d_loss = 5.521225929260254,g_loss = [array(4.491064, dtype=float32), array(4.491064, dtype=float32), array(4.491064, dtype=float32), array(0.05520969, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch = 5371,d_loss = 4.4909892082214355,100*d_loss = 5.520780012011528,g_loss = [array(4.4912343, dtype=float32), array(4.4912343, dtype=float32), array(4.4912343, dtype=float32), array(0.05520523, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch = 5372,d_loss = 4.491166114807129,100*d_loss = 5.522079020738602,g_loss = [array(4.4914217, dtype=float32), array(4.4914217, dtype=float32), array(4.4914217, dtype=float32), array(0.05521822, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5373,d_loss = 4.491332054138184,100*d_loss = 5.521632730960846,g_loss = [array(4.4915776, dtype=float32), array(4.4915776, dtype=float32), array(4.4915776, dtype=float32), array(0.05521376, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5374,d_loss = 4.491506576538086,100*d_loss = 5.52293136715889,g_loss = [array(4.4917636, dtype=float32), array(4.4917636, dtype=float32), array(4.4917636, dtype=float32), array(0.05522674, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch = 5375,d_loss = 4.491683483123779,100*d_loss = 5.522485077381134,g_loss = [array(4.4919195, dtype=float32), array(4.4919195, dtype=float32), array(4.4919195, dtype=float32), array(0.05522228, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 5376,d_loss = 4.491848468780518,100*d_loss = 5.523201823234558,g_loss = [array(4.492103, dtype=float32), array(4.492103, dtype=float32), array(4.492103, dtype=float32), array(0.05522945, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5377,d_loss = 4.492018699645996,100*d_loss = 5.523336678743362,g_loss = [array(4.492253, dtype=float32), array(4.492253, dtype=float32), array(4.492253, dtype=float32), array(0.0552308, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 5378,d_loss = 4.49216365814209,100*d_loss = 5.524053052067757,g_loss = [array(4.492401, dtype=float32), array(4.492401, dtype=float32), array(4.492401, dtype=float32), array(0.05523796, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 5379,d_loss = 4.4923248291015625,100*d_loss = 5.524768680334091,g_loss = [array(4.492577, dtype=float32), array(4.492577, dtype=float32), array(4.492577, dtype=float32), array(0.05524512, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 5380,d_loss = 4.492510795593262,100*d_loss = 5.523741990327835,g_loss = [array(4.492767, dtype=float32), array(4.492767, dtype=float32), array(4.492767, dtype=float32), array(0.05523485, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5381,d_loss = 4.4926862716674805,100*d_loss = 5.523876845836639,g_loss = [array(4.492929, dtype=float32), array(4.492929, dtype=float32), array(4.492929, dtype=float32), array(0.05523621, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5382,d_loss = 4.4928388595581055,100*d_loss = 5.524592474102974,g_loss = [array(4.493078, dtype=float32), array(4.493078, dtype=float32), array(4.493078, dtype=float32), array(0.05524336, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5383,d_loss = 4.492997169494629,100*d_loss = 5.523566156625748,g_loss = [array(4.4932423, dtype=float32), array(4.4932423, dtype=float32), array(4.4932423, dtype=float32), array(0.0552331, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 5384,d_loss = 4.4931488037109375,100*d_loss = 5.525442212820053,g_loss = [array(4.4933915, dtype=float32), array(4.4933915, dtype=float32), array(4.4933915, dtype=float32), array(0.05525186, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# epoch = 5385,d_loss = 4.4933061599731445,100*d_loss = 5.524996668100357,g_loss = [array(4.493544, dtype=float32), array(4.493544, dtype=float32), array(4.493544, dtype=float32), array(0.0552474, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 5386,d_loss = 4.493467330932617,100*d_loss = 5.5251311510801315,g_loss = [array(4.4937124, dtype=float32), array(4.4937124, dtype=float32), array(4.4937124, dtype=float32), array(0.05524875, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5387,d_loss = 4.493622779846191,100*d_loss = 5.5258456617593765,g_loss = [array(4.4938626, dtype=float32), array(4.4938626, dtype=float32), array(4.4938626, dtype=float32), array(0.05525589, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5388,d_loss = 4.493788719177246,100*d_loss = 5.52482008934021,g_loss = [array(4.4940295, dtype=float32), array(4.4940295, dtype=float32), array(4.4940295, dtype=float32), array(0.05524564, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch = 5389,d_loss = 4.493960857391357,100*d_loss = 5.524374917149544,g_loss = [array(4.494212, dtype=float32), array(4.494212, dtype=float32), array(4.494212, dtype=float32), array(0.05524119, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 5390,d_loss = 4.494133949279785,100*d_loss = 5.524509400129318,g_loss = [array(4.49438, dtype=float32), array(4.49438, dtype=float32), array(4.49438, dtype=float32), array(0.05524253, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5391,d_loss = 4.494290828704834,100*d_loss = 5.524644255638123,g_loss = [array(4.494529, dtype=float32), array(4.494529, dtype=float32), array(4.494529, dtype=float32), array(0.05524388, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5392,d_loss = 4.49445915222168,100*d_loss = 5.5236198008060455,g_loss = [array(4.494709, dtype=float32), array(4.494709, dtype=float32), array(4.494709, dtype=float32), array(0.05523364, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5393,d_loss = 4.4946441650390625,100*d_loss = 5.522595718502998,g_loss = [array(4.4948945, dtype=float32), array(4.4948945, dtype=float32), array(4.4948945, dtype=float32), array(0.0552234, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5394,d_loss = 4.494811534881592,100*d_loss = 5.522730574011803,g_loss = [array(4.495062, dtype=float32), array(4.495062, dtype=float32), array(4.495062, dtype=float32), array(0.05522475, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch = 5395,d_loss = 4.494974136352539,100*d_loss = 5.523444339632988,g_loss = [array(4.495218, dtype=float32), array(4.495218, dtype=float32), array(4.495218, dtype=float32), array(0.05523188, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch = 5396,d_loss = 4.495128154754639,100*d_loss = 5.5235788226127625,g_loss = [array(4.4953694, dtype=float32), array(4.4953694, dtype=float32), array(4.4953694, dtype=float32), array(0.05523323, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5397,d_loss = 4.495283126831055,100*d_loss = 5.523713678121567,g_loss = [array(4.495524, dtype=float32), array(4.495524, dtype=float32), array(4.495524, dtype=float32), array(0.05523458, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5398,d_loss = 4.495445251464844,100*d_loss = 5.524426698684692,g_loss = [array(4.495693, dtype=float32), array(4.495693, dtype=float32), array(4.495693, dtype=float32), array(0.05524171, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 5399,d_loss = 4.495614051818848,100*d_loss = 5.524561554193497,g_loss = [array(4.495865, dtype=float32), array(4.495865, dtype=float32), array(4.495865, dtype=float32), array(0.05524306, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# epoch = 5400,d_loss = 4.495792388916016,100*d_loss = 5.52411675453186,g_loss = [array(4.4960446, dtype=float32), array(4.4960446, dtype=float32), array(4.4960446, dtype=float32), array(0.05523861, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch = 5401,d_loss = 4.495968818664551,100*d_loss = 5.523094534873962,g_loss = [array(4.496216, dtype=float32), array(4.496216, dtype=float32), array(4.496216, dtype=float32), array(0.05522839, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# epoch = 5402,d_loss = 4.496145248413086,100*d_loss = 5.523229017853737,g_loss = [array(4.496399, dtype=float32), array(4.496399, dtype=float32), array(4.496399, dtype=float32), array(0.05522973, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# epoch = 5403,d_loss = 4.496328353881836,100*d_loss = 5.523363500833511,g_loss = [array(4.496577, dtype=float32), array(4.496577, dtype=float32), array(4.496577, dtype=float32), array(0.05523108, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5404,d_loss = 4.496499061584473,100*d_loss = 5.525810644030571,g_loss = [array(4.4967475, dtype=float32), array(4.4967475, dtype=float32), array(4.4967475, dtype=float32), array(0.05525555, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 5405,d_loss = 4.496670722961426,100*d_loss = 5.525944754481316,g_loss = [array(4.496918, dtype=float32), array(4.496918, dtype=float32), array(4.496918, dtype=float32), array(0.05525689, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5406,d_loss = 4.496840476989746,100*d_loss = 5.525500327348709,g_loss = [array(4.49709, dtype=float32), array(4.49709, dtype=float32), array(4.49709, dtype=float32), array(0.05525245, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5407,d_loss = 4.497026443481445,100*d_loss = 5.524478852748871,g_loss = [array(4.4972863, dtype=float32), array(4.4972863, dtype=float32), array(4.4972863, dtype=float32), array(0.05524223, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5408,d_loss = 4.49720573425293,100*d_loss = 5.525768548250198,g_loss = [array(4.4974537, dtype=float32), array(4.4974537, dtype=float32), array(4.4974537, dtype=float32), array(0.05525513, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5409,d_loss = 4.497375965118408,100*d_loss = 5.525324493646622,g_loss = [array(4.497618, dtype=float32), array(4.497618, dtype=float32), array(4.497618, dtype=float32), array(0.05525069, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 5410,d_loss = 4.497534275054932,100*d_loss = 5.524881184101105,g_loss = [array(4.4977746, dtype=float32), array(4.4977746, dtype=float32), array(4.4977746, dtype=float32), array(0.05524626, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# epoch = 5411,d_loss = 4.497689247131348,100*d_loss = 5.5250149220228195,g_loss = [array(4.497928, dtype=float32), array(4.497928, dtype=float32), array(4.497928, dtype=float32), array(0.0552476, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# epoch = 5412,d_loss = 4.497846603393555,100*d_loss = 5.525149032473564,g_loss = [array(4.498092, dtype=float32), array(4.498092, dtype=float32), array(4.498092, dtype=float32), array(0.05524894, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch = 5413,d_loss = 4.498007774353027,100*d_loss = 5.524128302931786,g_loss = [array(4.4982533, dtype=float32), array(4.4982533, dtype=float32), array(4.4982533, dtype=float32), array(0.05523873, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# epoch = 5414,d_loss = 4.498173236846924,100*d_loss = 5.5236853659152985,g_loss = [array(4.498406, dtype=float32), array(4.498406, dtype=float32), array(4.498406, dtype=float32), array(0.0552343, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# epoch = 5415,d_loss = 4.498312950134277,100*d_loss = 5.52266538143158,g_loss = [array(4.498541, dtype=float32), array(4.498541, dtype=float32), array(4.498541, dtype=float32), array(0.05522411, dtype=float32)]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
